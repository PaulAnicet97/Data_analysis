# %%
import warnings
warnings.filterwarnings("ignore")
import regex
import seaborn as sns
import pandas as pd
import os

# %%
df_metadados = pd.DataFrame()
path = '/Users/kpaul/OneDrive/code/github/Project/data_analysis/OLX/dados/'

for arquivo in os.listdir(path):
    print(arquivo)
    df_metadados = pd.concat([df_metadados, pd.read_csv(path + arquivo)])
    
df_metadados.reset_index(drop=True,inplace=True)
# Out:
# metadados_olx_telephones_202210232103.csv
# metadados_olx_telephones_202210232104.csv
# metadados_olx_telephones_202210232105.csv
# metadados_olx_telephones_202210232106.csv
# metadados_olx_telephones_202210232107.csv
# metadados_olx_telephones_202210232108.csv

# %%
df_metadados2 = df_metadados.drop_duplicates(subset=['ID'])
df_metadados.reset_index(drop=True,inplace=True)
print(df_metadados2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4809 entries, 0 to 16809
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     4809 non-null   int64
#  1   TITULO                 4809 non-null   object
#  2   VALOR                  4717 non-null   object
#  3   LOCAL                  4809 non-null   object
#  4   DATA_ANUNCIO           4809 non-null   object
#  5   LINK                   4809 non-null   object
#  6   DATA_COLETA_METADADOS  4809 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 300.6+ KB
# None

# %%
dados = df_metadados2.copy()
(dados.isnull().sum()/len(dados)*100).sort_values(ascending=False)
# Out:
# VALOR                    1.91308
# ID                       0.00000
# TITULO                   0.00000
# LOCAL                    0.00000
# DATA_ANUNCIO             0.00000
# LINK                     0.00000
# DATA_COLETA_METADADOS    0.00000
# dtype: float64

# %%
dados.reset_index(drop = True, inplace = True)
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     4809 non-null   int64
#  1   TITULO                 4809 non-null   object
#  2   VALOR                  4717 non-null   object
#  3   LOCAL                  4809 non-null   object
#  4   DATA_ANUNCIO           4809 non-null   object
#  5   LINK                   4809 non-null   object
#  6   DATA_COLETA_METADADOS  4809 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 263.1+ KB

# %%
dados.dropna(subset = ['VALOR'], inplace = True)
dados.head()
# Out:
#            ID                                             TITULO     VALOR  \
# 0  1099084653                Iphone 12 Pro Max, 256 GB, Graphite  R$ 6.000
# 1  1100742919                              Motorola Moto G7 Play    R$ 650
# 2  1100742895                                            iPhone     R$ 900
# 3  1100742892                                         Iphone 6s     R$ 450
# 4  1073862676  Apple Watch 7 Até 12X ( Super Promoção Hoje!! ...  R$ 2.380
#
#                   LOCAL DATA_ANUNCIO  \
# 0  Rio de Janeiro -  RJ  Hoje, 20:54
# 1          Canoas -  RS  Hoje, 20:54
# 2        Salvador -  BA  Hoje, 20:54
# 3         Palhoça -  SC  Hoje, 20:54
# 4        Brasília -  DF  Hoje, 20:54
#
#                                                 LINK DATA_COLETA_METADADOS
# 0  https://rj.olx.com.br/rio-de-janeiro-e-regiao/...            2022-10-23
# 1  https://rs.olx.com.br/regioes-de-porto-alegre-...            2022-10-23
# 2  https://ba.olx.com.br/grande-salvador/celulare...            2022-10-23
# 3  https://sc.olx.com.br/florianopolis-e-regiao/c...            2022-10-23
# 4  https://df.olx.com.br/distrito-federal-e-regia...            2022-10-23

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4717 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     4717 non-null   int64
#  1   TITULO                 4717 non-null   object
#  2   VALOR                  4717 non-null   object
#  3   LOCAL                  4717 non-null   object
#  4   DATA_ANUNCIO           4717 non-null   object
#  5   LINK                   4717 non-null   object
#  6   DATA_COLETA_METADADOS  4717 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 294.8+ KB

# %% [markdown]
# # Trabalhando na coluna valor
# Objetivo é deixar essa coluna em formato int e dropar valores estranhos

# %%
# tirando o simbolo do reais
val = dados['VALOR'].str.split(' ', expand=True)
dados['VALOR'] = val[1]
dados
# Out:
#               ID                                             TITULO  VALOR  \
# 0     1099084653                Iphone 12 Pro Max, 256 GB, Graphite  6.000
# 1     1100742919                              Motorola Moto G7 Play    650
# 2     1100742895                                            iPhone     900
# 3     1100742892                                         Iphone 6s     450
# 4     1073862676  Apple Watch 7 Até 12X ( Super Promoção Hoje!! ...  2.380
# ...          ...                                                ...    ...
# 4804  1100722954                                     Vendo esse j8     250
# 4805  1100722956                                iPhone 8 Plus novo   2.100
# 4806  1100722960                                           Moto g8     270
# 4807  1100722961                                                G30      0
# 4808  1100722972                          Samsung A80 ótimo estado   1.200
#
#                      LOCAL DATA_ANUNCIO  \
# 0     Rio de Janeiro -  RJ  Hoje, 20:54
# 1             Canoas -  RS  Hoje, 20:54
# 2           Salvador -  BA  Hoje, 20:54
# 3            Palhoça -  SC  Hoje, 20:54
# 4           Brasília -  DF  Hoje, 20:54
# ...                    ...          ...
# 4804      Rio Branco -  AC  Hoje, 19:40
# 4805        São Luís -  MA  Hoje, 19:40
# 4806        Sorocaba -  SP  Hoje, 19:40
# 4807        São Luís -  MA  Hoje, 19:40
# 4808    Praia Grande -  SP  Hoje, 19:40
#
#                                                    LINK DATA_COLETA_METADADOS
# 0     https://rj.olx.com.br/rio-de-janeiro-e-regiao/...            2022-10-23
# 1     https://rs.olx.com.br/regioes-de-porto-alegre-...            2022-10-23
# 2     https://ba.olx.com.br/grande-salvador/celulare...            2022-10-23
# 3     https://sc.olx.com.br/florianopolis-e-regiao/c...            2022-10-23
# 4     https://df.olx.com.br/distrito-federal-e-regia...            2022-10-23
# ...                                                 ...                   ...
# 4804  https://ac.olx.com.br/acre/celulares/vendo-ess...            2022-10-23
# 4805  https://ma.olx.com.br/regiao-de-sao-luis/celul...            2022-10-23
# 4806  https://sp.olx.com.br/regiao-de-sorocaba/celul...            2022-10-23
# 4807  https://ma.olx.com.br/regiao-de-sao-luis/celul...            2022-10-23
# 4808  https://sp.olx.com.br/baixada-santista-e-litor...            2022-10-23
#
# [4717 rows x 7 columns]

# %%
#suprimindo todos os pontos
a = dados['VALOR']
lista = [ str(i).replace('.' ,'') for i in  a]
dados['VALOR'] = lista
dados.head()
# Out:
#            ID                                             TITULO VALOR  \
# 0  1099084653                Iphone 12 Pro Max, 256 GB, Graphite  6000
# 1  1100742919                              Motorola Moto G7 Play   650
# 2  1100742895                                            iPhone    900
# 3  1100742892                                         Iphone 6s    450
# 4  1073862676  Apple Watch 7 Até 12X ( Super Promoção Hoje!! ...  2380
#
#                   LOCAL DATA_ANUNCIO  \
# 0  Rio de Janeiro -  RJ  Hoje, 20:54
# 1          Canoas -  RS  Hoje, 20:54
# 2        Salvador -  BA  Hoje, 20:54
# 3         Palhoça -  SC  Hoje, 20:54
# 4        Brasília -  DF  Hoje, 20:54
#
#                                                 LINK DATA_COLETA_METADADOS
# 0  https://rj.olx.com.br/rio-de-janeiro-e-regiao/...            2022-10-23
# 1  https://rs.olx.com.br/regioes-de-porto-alegre-...            2022-10-23
# 2  https://ba.olx.com.br/grande-salvador/celulare...            2022-10-23
# 3  https://sc.olx.com.br/florianopolis-e-regiao/c...            2022-10-23
# 4  https://df.olx.com.br/distrito-federal-e-regia...            2022-10-23

# %%
#suprimindo valores em formato de parcela ou seja que contem um "x"
dados = dados[dados['VALOR'].str.contains('x')== False]
dados.head(20)
# Out:
#             ID                                             TITULO VALOR  \
# 0   1099084653                Iphone 12 Pro Max, 256 GB, Graphite  6000
# 1   1100742919                              Motorola Moto G7 Play   650
# 2   1100742895                                            iPhone    900
# 3   1100742892                                         Iphone 6s    450
# 4   1073862676  Apple Watch 7 Até 12X ( Super Promoção Hoje!! ...  2380
# 5   1100742865                                      iPhone 7plus    920
# 6   1037408731  IPHONE XSMAX 256 GB SEMI NOVOS DE VITRINE COM ...  3350
# 7   1058809777                            iPhone X 64Gb Seminovo   2399
# 8   1100742843                 iPhone 8 Plus 128gb 88 de bateria   1300
# 9   1100742837                              iPhone 11 64 GB novo   2990
# 10  1023389133                    IPHONE XS MAX 64 GB SEMI NOVOS   3250
# 11  1100742834                                          Iphone 6s   350
# 12  1100742828                        Vendo Edge 20 Pro  (256 gb)  2300
# 13  1073057148  Apple Watch 7 Até 12X ( Super Promoção Hoje, T...  2380
# 14  1100742740                                    iPhone 12 128GB  3600
# 15  1100742725                                           Iphone 7   800
# 16  1100742695                          iPhone 11 64 GB  lacrado   3000
# 17  1100742659               iPhone 11 + fone de ouvido sem fio !  2800
# 18  1100742633                           Iphone XR 128gb - Branco  2867
# 20  1099573952                  Samsung S21 FE 5G na caixa com NF  3900
#
#                               LOCAL DATA_ANUNCIO  \
# 0              Rio de Janeiro -  RJ  Hoje, 20:54
# 1                      Canoas -  RS  Hoje, 20:54
# 2                    Salvador -  BA  Hoje, 20:54
# 3                     Palhoça -  SC  Hoje, 20:54
# 4                    Brasília -  DF  Hoje, 20:54
# 5                    Campinas -  SP  Hoje, 20:54
# 6              Belo Horizonte -  MG  Hoje, 20:54
# 7                Porto Alegre -  RS  Hoje, 20:54
# 8              Rio de Janeiro -  RJ  Hoje, 20:54
# 9   Santo Amaro da Imperatriz -  SC  Hoje, 20:54
# 10             Belo Horizonte -  MG  Hoje, 20:54
# 11               Juiz de Fora -  MG  Hoje, 20:54
# 12             Rio de Janeiro -  RJ  Hoje, 20:53
# 13                   Brasília -  DF  Hoje, 20:53
# 14                Nova Iguaçu -  RJ  Hoje, 20:53
# 15                     Olinda -  PE  Hoje, 20:53
# 16               Juiz de Fora -  MG  Hoje, 20:53
# 17                   Brasília -  DF  Hoje, 20:53
# 18                   Contagem -  MG  Hoje, 20:53
# 20                     Manaus -  AM  Hoje, 20:52
#
#                                                  LINK DATA_COLETA_METADADOS
# 0   https://rj.olx.com.br/rio-de-janeiro-e-regiao/...            2022-10-23
# 1   https://rs.olx.com.br/regioes-de-porto-alegre-...            2022-10-23
# 2   https://ba.olx.com.br/grande-salvador/celulare...            2022-10-23
# 3   https://sc.olx.com.br/florianopolis-e-regiao/c...            2022-10-23
# 4   https://df.olx.com.br/distrito-federal-e-regia...            2022-10-23
# 5   https://sp.olx.com.br/grande-campinas/celulare...            2022-10-23
# 6   https://mg.olx.com.br/belo-horizonte-e-regiao/...            2022-10-23
# 7   https://rs.olx.com.br/regioes-de-porto-alegre-...            2022-10-23
# 8   https://rj.olx.com.br/rio-de-janeiro-e-regiao/...            2022-10-23
# 9   https://sc.olx.com.br/florianopolis-e-regiao/c...            2022-10-23
# 10  https://mg.olx.com.br/belo-horizonte-e-regiao/...            2022-10-23
# 11  https://mg.olx.com.br/regiao-de-juiz-de-fora/c...            2022-10-23
# 12  https://rj.olx.com.br/rio-de-janeiro-e-regiao/...            2022-10-23
# 13  https://df.olx.com.br/distrito-federal-e-regia...            2022-10-23
# 14  https://rj.olx.com.br/rio-de-janeiro-e-regiao/...            2022-10-23
# 15  https://pe.olx.com.br/grande-recife/celulares/...            2022-10-23
# 16  https://mg.olx.com.br/regiao-de-juiz-de-fora/c...            2022-10-23
# 17  https://df.olx.com.br/distrito-federal-e-regia...            2022-10-23
# 18  https://mg.olx.com.br/belo-horizonte-e-regiao/...            2022-10-23
# 20  https://am.olx.com.br/regiao-de-manaus/celular...            2022-10-23

# %%
# agora vamos colocar a coluna em formato int
dados['VALOR'] = dados['VALOR'].astype('int')
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4717 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     4717 non-null   int64
#  1   TITULO                 4717 non-null   object
#  2   VALOR                  4717 non-null   int32
#  3   LOCAL                  4717 non-null   object
#  4   DATA_ANUNCIO           4717 non-null   object
#  5   LINK                   4717 non-null   object
#  6   DATA_COLETA_METADADOS  4717 non-null   object
# dtypes: int32(1), int64(1), object(5)
# memory usage: 276.4+ KB

# %%
#dados2 = dados2[(dados2['VALOR'] > 500) & (dados2['VALOR'] <= 15000) ]
#dados2

# %% [markdown]
# # Trabalhando na coluna local
# objetivo é poder extrair o estado de cada publicação

# %%
dados['LOCAL'] = dados['LOCAL'].str.lower()
a = dados['LOCAL'].str[-2:]
dados['Estado'] = a
dados
# Out:
#               ID                                             TITULO  VALOR  \
# 0     1099084653                Iphone 12 Pro Max, 256 GB, Graphite   6000
# 1     1100742919                              Motorola Moto G7 Play    650
# 2     1100742895                                            iPhone     900
# 3     1100742892                                         Iphone 6s     450
# 4     1073862676  Apple Watch 7 Até 12X ( Super Promoção Hoje!! ...   2380
# ...          ...                                                ...    ...
# 4804  1100722954                                     Vendo esse j8     250
# 4805  1100722956                                iPhone 8 Plus novo    2100
# 4806  1100722960                                           Moto g8     270
# 4807  1100722961                                                G30      0
# 4808  1100722972                          Samsung A80 ótimo estado    1200
#
#                      LOCAL DATA_ANUNCIO  \
# 0     rio de janeiro -  rj  Hoje, 20:54
# 1             canoas -  rs  Hoje, 20:54
# 2           salvador -  ba  Hoje, 20:54
# 3            palhoça -  sc  Hoje, 20:54
# 4           brasília -  df  Hoje, 20:54
# ...                    ...          ...
# 4804      rio branco -  ac  Hoje, 19:40
# 4805        são luís -  ma  Hoje, 19:40
# 4806        sorocaba -  sp  Hoje, 19:40
# 4807        são luís -  ma  Hoje, 19:40
# 4808    praia grande -  sp  Hoje, 19:40
#
#                                                    LINK DATA_COLETA_METADADOS  \
# 0     https://rj.olx.com.br/rio-de-janeiro-e-regiao/...            2022-10-23
# 1     https://rs.olx.com.br/regioes-de-porto-alegre-...            2022-10-23
# 2     https://ba.olx.com.br/grande-salvador/celulare...            2022-10-23
# 3     https://sc.olx.com.br/florianopolis-e-regiao/c...            2022-10-23
# 4     https://df.olx.com.br/distrito-federal-e-regia...            2022-10-23
# ...                                                 ...                   ...
# 4804  https://ac.olx.com.br/acre/celulares/vendo-ess...            2022-10-23
# 4805  https://ma.olx.com.br/regiao-de-sao-luis/celul...            2022-10-23
# 4806  https://sp.olx.com.br/regiao-de-sorocaba/celul...            2022-10-23
# 4807  https://ma.olx.com.br/regiao-de-sao-luis/celul...            2022-10-23
# 4808  https://sp.olx.com.br/baixada-santista-e-litor...            2022-10-23
#
#      Estado
# 0        rj
# 1        rs
# 2        ba
# 3        sc
# 4        df
# ...     ...
# 4804     ac
# 4805     ma
# 4806     sp
# 4807     ma
# 4808     sp
#
# [4717 rows x 8 columns]

# %% [markdown]
# # trabalhando na coluna Titulo
# o objetivo é identificar a marca de cada celular e criar uma nova coluna

# %%
dados.reset_index(drop = True , inplace =True)

# %%
#convertendo toda a coluna em miusculo
dados['TITULO'] = dados['TITULO'].str.lower()
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4717 entries, 0 to 4716
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     4717 non-null   int64
#  1   TITULO                 4717 non-null   object
#  2   VALOR                  4717 non-null   int32
#  3   LOCAL                  4717 non-null   object
#  4   DATA_ANUNCIO           4717 non-null   object
#  5   LINK                   4717 non-null   object
#  6   DATA_COLETA_METADADOS  4717 non-null   object
#  7   Estado                 4717 non-null   object
# dtypes: int32(1), int64(1), object(6)
# memory usage: 276.5+ KB

# %%
iphone = ["iphone", "apple", "13 pro" , "12 pro", "11 pro", "xr" , "8 plus" ]
samsung = ["samsung" ,"galaxy" , "j8" , "a50" , "s6" , "a30" ,  "a30s" , "a22" , "s22" , "j7" , "sansung" , "a13" , "a32" , "s21" , "s20" , "s9" ,"j5" , "a21s" , "a21" , "a10" , "a20", "a72", "a31" , "a03", "j2" , "j4" , "a70" , "a20s" , " a10s" , "a02"]
xiaomi = ["xiaomi", "redmi" , "mi 11" , "xiome" ,"note" ,"poco" , "realme" , "redimi" ,"xaiomi"]
motorola = ["motorola", "moto" , "g8" , "g5" , "mto" , "g9"]
listatest =dados["TITULO"].to_list()

# %%
dados.reset_index(drop = True , inplace =True) 
lista = []
for i in dados["TITULO"]:
    if "iphone"in i or "13 pro" in i or "12 pro" in i or "11 pro" in i or "xr" in i or "8 plus" in i:
       lista.append("Iphone")
    elif "samsung" in i  or "galaxy" in i or "j8" in i or "a50" in i or "s6" in i or "a30" in i or  "a30s" in i or "a22" in i  or "s22" in i  or "j7" in i  or "sansung" in i or "a13" in i or "a32" in i  or "s21" in i  or "s20" in i or "s9" in i  or"j5" in i  or "a21s" in i or "a21" in i or "a10" in i  or "a20" in i or "a72" in i or "a31"  in i or "a03" in i  or "j2" in i or "j4" in i or "a70"  in i or "a20s"  in i or" a10s"  in i or"a02" in i or "a12" in i :
        lista.append("Samsung")
    elif "xiaomi" in i or "redmi" in i or "mi 11" in i  or "xiome" in i or "xiomi" in i or "note" in i  or "poco"in i  or "realme"in i or "redimi"in i  or "xaiomi" in i or " mi light" in i:
        lista.append("Xiaomi")
    elif "lg" in i:
        lista.append("Lg")
    elif "motorola" in i or "moto" in i or "g8" in i or "g5" in i or  "mto" in i or "g9" in i :
        lista.append("Motorola")
    elif "nokia" in i:
        lista.append("Nokia")
    elif "asus" in i:
        lista.append("Asus")
    elif "huawei" in i:
        lista.append("Huawei")
    elif "lenovo" in i:
        lista.append("Lenovo")
    elif "google" in i or "pixel" in i:
        lista.append("Google Phone")
    elif "troca" in i or "troco" in i:
      lista.append("Troca")
    elif "notebook" in i or "computador" in i:
      lista.append("Notebok")
    elif "fone" in i or "phone" in i or "buds" in i or "bud" in i or "airpod"  in i or "airpods" in i:
      lista.append("Fone")
    elif "watch" in i or "smartwatch" in i or "relogío" in i:
      lista.append("Watch")
    else:
        lista.append("Other")
    
dados["marcas"] = pd.DataFrame(lista)
dados
# Out:
#               ID                                             TITULO  VALOR  \
# 0     1099084653                iphone 12 pro max, 256 gb, graphite   6000
# 1     1100742919                              motorola moto g7 play    650
# 2     1100742895                                            iphone     900
# 3     1100742892                                         iphone 6s     450
# 4     1073862676  apple watch 7 até 12x ( super promoção hoje!! ...   2380
# ...          ...                                                ...    ...
# 4712  1100722954                                     vendo esse j8     250
# 4713  1100722956                                iphone 8 plus novo    2100
# 4714  1100722960                                           moto g8     270
# 4715  1100722961                                                g30      0
# 4716  1100722972                          samsung a80 ótimo estado    1200
#
#                      LOCAL DATA_ANUNCIO  \
# 0     rio de janeiro -  rj  Hoje, 20:54
# 1             canoas -  rs  Hoje, 20:54
# 2           salvador -  ba  Hoje, 20:54
# 3            palhoça -  sc  Hoje, 20:54
# 4           brasília -  df  Hoje, 20:54
# ...                    ...          ...
# 4712      rio branco -  ac  Hoje, 19:40
# 4713        são luís -  ma  Hoje, 19:40
# 4714        sorocaba -  sp  Hoje, 19:40
# 4715        são luís -  ma  Hoje, 19:40
# 4716    praia grande -  sp  Hoje, 19:40
#
#                                                    LINK DATA_COLETA_METADADOS  \
# 0     https://rj.olx.com.br/rio-de-janeiro-e-regiao/...            2022-10-23
# 1     https://rs.olx.com.br/regioes-de-porto-alegre-...            2022-10-23
# 2     https://ba.olx.com.br/grande-salvador/celulare...            2022-10-23
# 3     https://sc.olx.com.br/florianopolis-e-regiao/c...            2022-10-23
# 4     https://df.olx.com.br/distrito-federal-e-regia...            2022-10-23
# ...                                                 ...                   ...
# 4712  https://ac.olx.com.br/acre/celulares/vendo-ess...            2022-10-23
# 4713  https://ma.olx.com.br/regiao-de-sao-luis/celul...            2022-10-23
# 4714  https://sp.olx.com.br/regiao-de-sorocaba/celul...            2022-10-23
# 4715  https://ma.olx.com.br/regiao-de-sao-luis/celul...            2022-10-23
# 4716  https://sp.olx.com.br/baixada-santista-e-litor...            2022-10-23
#
#      Estado    marcas
# 0        rj    Iphone
# 1        rs  Motorola
# 2        ba    Iphone
# 3        sc    Iphone
# 4        df     Watch
# ...     ...       ...
# 4712     ac   Samsung
# 4713     ma    Iphone
# 4714     sp  Motorola
# 4715     ma     Other
# 4716     sp   Samsung
#
# [4717 rows x 9 columns]

# %%
#vamos trabalhar com apenas anuncios em cima de 100 reais
dados = dados[dados["VALOR"] >= 100]
dados = dados[(dados["marcas"] != "Notebook") | (dados["marcas"] != "Fone") | (dados["marcas"] != "Troca") | (dados["marcas"] != "Watch")]

# %%
# vamo criar um data frame para observar os valores "other"
ot = dados[dados["marcas"] == "Other"]
ot.reset_index(drop= True , inplace = True)
ot
# Out:
#              ID                                  TITULO  VALOR  \
# 0    1100742828             vendo edge 20 pro  (256 gb)   2300
# 1    1100741950   tenho 2 radio comunicador dep 450 uhf   1500
# 2    1100741383               carregador original appel    800
# 3    1100741291                           vende celular   2500
# 4    1100741260                         vender tudo 250    250
# ..          ...                                     ...    ...
# 392  1100724136                  14 pro max 128 lacrado   8990
# 393  1100723438           titularidade maquininha stone    220
# 394  1100723598                                 celular    350
# 395  1100723619                vende-se vivo x70 pro 5g   4300
# 396  1100723277                            ipad mini 3     850
#
#                       LOCAL DATA_ANUNCIO  \
# 0      rio de janeiro -  rj  Hoje, 20:53
# 1           fortaleza -  ce  Hoje, 20:50
# 2           são paulo -  sp  Hoje, 20:46
# 3    feira de santana -  ba  Hoje, 20:46
# 4             goiânia -  go  Hoje, 20:46
# ..                      ...          ...
# 392        cosmópolis -  sp  Hoje, 19:41
# 393          curitiba -  pr  Hoje, 19:40
# 394       joão pessoa -  pb  Hoje, 19:40
# 395         boa vista -  rr  Hoje, 19:40
# 396          sorocaba -  sp  Hoje, 19:40
#
#                                                   LINK DATA_COLETA_METADADOS  \
# 0    https://rj.olx.com.br/rio-de-janeiro-e-regiao/...            2022-10-23
# 1    https://ce.olx.com.br/fortaleza-e-regiao/celul...            2022-10-23
# 2    https://sp.olx.com.br/sao-paulo-e-regiao/celul...            2022-10-23
# 3    https://ba.olx.com.br/regiao-de-feira-de-santa...            2022-10-23
# 4    https://go.olx.com.br/grande-goiania-e-anapoli...            2022-10-23
# ..                                                 ...                   ...
# 392  https://sp.olx.com.br/grande-campinas/celulare...            2022-10-23
# 393  https://pr.olx.com.br/regiao-de-curitiba-e-par...            2022-10-23
# 394  https://pb.olx.com.br/paraiba/celulares/celula...            2022-10-23
# 395  https://rr.olx.com.br/roraima/celulares/vende-...            2022-10-23
# 396  https://sp.olx.com.br/regiao-de-sorocaba/celul...            2022-10-23
#
#     Estado marcas
# 0       rj  Other
# 1       ce  Other
# 2       sp  Other
# 3       ba  Other
# 4       go  Other
# ..     ...    ...
# 392     sp  Other
# 393     pr  Other
# 394     pb  Other
# 395     rr  Other
# 396     sp  Other
#
# [397 rows x 9 columns]

# %%
data_final = dados[dados["marcas"]  != "Other"]
data_final = data_final[["ID", "TITULO", "VALOR", "Estado", "marcas"]]
data_final
# Out:
#               ID                                             TITULO  VALOR  \
# 0     1099084653                iphone 12 pro max, 256 gb, graphite   6000
# 1     1100742919                              motorola moto g7 play    650
# 2     1100742895                                            iphone     900
# 3     1100742892                                         iphone 6s     450
# 4     1073862676  apple watch 7 até 12x ( super promoção hoje!! ...   2380
# ...          ...                                                ...    ...
# 4711  1100722952                                         a12 branco    300
# 4712  1100722954                                     vendo esse j8     250
# 4713  1100722956                                iphone 8 plus novo    2100
# 4714  1100722960                                           moto g8     270
# 4716  1100722972                          samsung a80 ótimo estado    1200
#
#      Estado    marcas
# 0        rj    Iphone
# 1        rs  Motorola
# 2        ba    Iphone
# 3        sc    Iphone
# 4        df     Watch
# ...     ...       ...
# 4711     am   Samsung
# 4712     ac   Samsung
# 4713     ma    Iphone
# 4714     sp  Motorola
# 4716     sp   Samsung
#
# [3976 rows x 5 columns]

# %%
data_final.value_counts("marcas").plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='marcas'>

# %%
sns.countplot(data_final, y= "Estado")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Estado'>
