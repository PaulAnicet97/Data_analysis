# %% [markdown]
# <a href="https://colab.research.google.com/github/Aklunon/Projeto-OLX/blob/main/Valor_Telephones_Br.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pacotes para webscrapping
from bs4 import BeautifulSoup
import requests
import time
import random
import pandas as pd
from datetime import datetime

# %%
# DEFININDO A PÁGINA QUE SERÁ EXTRAÍDA
url_inicial = 'https://olx.com.br/celulares?o=1'

# ACESSANDO PÁGINA|
pagina_inicial = requests.get(url_inicial)
print(pagina_inicial) # response 200 conexão OK, outros valores houve algum problema'

# ACESSANDO PÁGINA|
pagina_inicial = requests.get(url_inicial)
print(pagina_inicial) # response 200 conexão OK, outros valores houve algum problema
# Out:
# <Response [403]>
# <Response [403]>

# %%
# DEFININDO A PÁGINA QUE SERÁ EXTRAÍDA

## CRIANDO USER-AGENTE PARA AUTENTICAR NO SITE. 
# SEM ISSO O SITE OLX BLOQUEIA O ACESSO A PÁGINA
headers = {
    'User-Agent': "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.93 Safari/537.36",
}

# ACESSANDO PÁGINA
pagina_inicial = requests.get(url_inicial, headers=headers)
print(pagina_inicial) # response 200 conexão OK, outros valores, houve algum problema
# Out:
# <Response [200]>

# %%
Classe_global = "h3us20-6 kMhCAe"

Classe_title = "sc-12rk7z2-7 kDVQFY" 

Classe_price = "sc-1kn4z61-1 dGMPPn"

Classe_location = "sc-12rk7z2-17 rRQgw"

Classe_post_time = "sc-11h4wdr-0 javKJU sc-ifAKCX fCbscF"

Link_class = "sc-12rk7z2-1 huFwya sc-htoDjs fpYhGm"

#ID_name = data-lurker_list_id

# %%
type(pagina_inicial.content)
# Out:
# bytes

# %%
new_page_inicial=BeautifulSoup(pagina_inicial.content, 'html.parser')

# %%
## EXTRAINDO VÁRIOS ANUNCIOS
anuncios = new_page_inicial.find_all(class_=Classe_global)
anuncios[:5]
# Out:
# [<div class="h3us20-6 kMhCAe"><div class="h3us20-4 iThXCX"><div><div class="sc-1fcmfeb-0 HutRS"><ul class="sc-1fcmfeb-1 kntIvV" id="ad-list"><li class="sc-1fcmfeb-2 iezWpY"><div class="sc-12rk7z2-0 jdIDkd"><a class="sc-12rk7z2-1 huFwya sc-htoDjs fpYhGm" data-ds-component="DS-Link" data-lurker-detail="list_id" data-lurker_is_featured="1" data-lurker_last_bump_age_secs="488" data-lurker_list_id="1099084653" data-lurker_list_position="0" data-lurker_olx_delivery_enabled="true" data-lurker_olx_pay_enabled="true" data-lurker_vehicle_report_enabled="false" href="https://rj.olx.com.br/rio-de-janeiro-e-regiao/celulares/iphone-12-pro-max-256-gb-graphite-1099084653" target="_blank" title="Iphone 12 Pro Max, 256 GB, Graphite"><div class="sc-12rk7z2-2 gSNULD"><div class="sc-1ion3fe-0 khoztA"><div><div class="sc-101cdir-0 gjneWt"><img alt="Título do anúncio: Iphone 12 Pro Max, 256 GB, Graphite" height="100%" loading="lazy" src="https://img.olx.com.br/thumbs256x256/84/842260458734259.jpg" width="100%"/></div></div><div class="sc-1ion3fe-1 cIJNya"><div><div class="sc-1n4y6ur-0 kyhiUC"><div class="sc-1n4y6ur-4 pWUxf"><svg class="sc-1n4y6ur-2 bbhdCb" color="var(--color-neutral-lightest)" height="16" size="16" viewbox="0 0 24 24" width="16" xmlns="http://www.w3.org/2000/svg"><path d="M17.401 5.25H21A2.75 2.75 0 0123.75 8v11A2.75 2.75 0 0121 21.75H3A2.75 2.75 0 01.25 19V8A2.75 2.75 0 013 5.25h3.599l1.777-2.666A.75.75 0 019 2.25h6a.75.75 0 01.624.334l1.777 2.666zm-8-1.5L7.624 6.416A.75.75 0 017 6.75H3c-.69 0-1.25.56-1.25 1.25v11c0 .69.56 1.25 1.25 1.25h18c.69 0 1.25-.56 1.25-1.25V8c0-.69-.56-1.25-1.25-1.25h-4a.75.75 0 01-.624-.334L14.599 3.75H9.4zm2.599 14a4.75 4.75 0 110-9.5 4.75 4.75 0 010 9.5zm0-1.5a3.25 3.25 0 100-6.5 3.25 3.25 0 000 6.5z" fill="var(--color-neutral-lightest)" fill-rule="evenodd"></path></svg><span aria-label="Quantidade de fotos do anúncio: 5." class="sc-1n4y6ur-1 bzUofP sc-ifAKCX fdOMeZ" color="--color-neutral-lightest" data-ds-component="DS-Text" display="block">5</span><div class="h3us20-5 cdUZWU"></div></div></div></div><div class="sc-1ion3fe-2 hHqPTj"></div><div><div class="sc-7x3hu8-0 fKOLao"><span aria-label="Item em destaque." class="sc-7x3hu8-1 kiBSyL sc-ifAKCX cEubYc" color="--color-neutral-lightest" data-ds-component="DS-Text" display="block">DESTAQUE</span></div></div></div></div><div class="sc-12rk7z2-3 fqDYpJ"><div class="sc-12rk7z2-4 dWYMAi"><div class="sc-12rk7z2-5 gZuhWp"><div class="sc-12rk7z2-7 kDVQFY"><div><h2 aria-hidden="true" class="kgl1mq-0 eFXRHn sc-ifAKCX FMjsQ" color="--color-neutral-darkest" data-ds-component="DS-Text" display="block" title="Iphone 12 Pro Max, 256 GB, Graphite">Iphone 12 Pro Max, 256 GB, Graphite</h2></div></div><div class="sc-12rk7z2-11 bXnrWQ"><div><div class="sc-1kn4z61-0 ikBDtl"><div class="sc-1kn4z61-1 dGMPPn"><span aria-label="Preço do item: R$ 6.000." class="m7nrfa-0 eJCbzj sc-ifAKCX ANnoQ" color="--color-neutral-darkest" data-ds-component="DS-Text" display="block">R$ 6.000</span></div><div class="sc-1kn4z61-2 RAyVy"><span class="djexd8-0 eHIWLE sc-ifAKCX fCbscF" color="--color-neutral-darkest" data-ds-component="DS-Text" display="block">12x de R$ 500,00</span></div></div></div></div><div class="sc-12rk7z2-10 ejffAZ"><div><button class="km45y6-0 kwiJGa sc-gGBfsJ hwrgmE" data-ds-component="DS-Button" data-lurker-detail="favorite" data-lurker_list_id="1099084653" data-testid="favorite"><svg color="#4a4a4a" height="16" size="16" viewbox="0 0 24 24" width="16" xmlns="http://www.w3.org/2000/svg"><path d="M20.141 11.92A4.637 4.637 0 0016.861 4c-1.23 0-2.41.489-3.28 1.36l-.52.52a1.5 1.5 0 01-2.122 0l-.52-.52a4.639 4.639 0 00-6.56 6.56l8.14 8.14 8.142-8.14zM12 4.818l.52-.52A6.14 6.14 0 1121.2 12.98l-8.68 8.681a.737.737 0 01-1.042 0l-8.681-8.68a6.139 6.139 0 018.682-8.682l.52.52z" fill="#4a4a4a" fill-rule="evenodd"></path></svg><span class="sc-dnqmqq iKiWfO">Adicionar aos favoritos</span></button></div></div></div><div class="sc-12rk7z2-5 sc-12rk7z2-6 XZIpN"><div class="sc-12rk7z2-8  ...

# %%
## CONVERTENDO ANÚNCIOS PARA TEXTO
[x.get_text() for x in anuncios]
# Out:
# ['5DESTAQUEIphone 12 Pro Max, 256 GB, GraphiteR$ 6.00012x de R$ 500,00Adicionar aos favoritosCompra SeguraParcelamento sem jurosDesconto no freteDeliveryRio de Janeiro -  RJHoje, 20:542Motorola Moto G7 PlayR$ 650Adicionar aos favoritosOnlineCanoas -  RSHoje, 20:545iPhone R$ 900Adicionar aos favoritosSalvador -  BAHoje, 20:543Iphone 6s R$ 45012x de R$ 37,50Adicionar aos favoritosOnlineCompra SeguraParcelamento sem jurosDesconto no freteDeliveryPalhoça -  SCHoje, 20:542Apple Watch 7 Até 12X ( Super Promoção Hoje!! ) Toda Linha Apple!!R$ 2.380Adicionar aos favoritosProfissionalBrasília -  DFHoje, 20:546iPhone 7plus R$ 920Adicionar aos favoritosOnlineCampinas -  SPHoje, 20:546IPHONE XSMAX 256 GB SEMI NOVOS DE VITRINE COM GARANTIA R$ 3.350Adicionar aos favoritosProfissionalBelo Horizonte -  MGHoje, 20:545iPhone X 64Gb Seminovo R$ 2.399Adicionar aos favoritosProfissionalPorto Alegre -  RSHoje, 20:543iPhone 8 Plus 128gb 88 de bateria R$ 1.300Adicionar aos favoritosOnlineRio de Janeiro -  RJHoje, 20:541iPhone 11 64 GB novo R$ 2.990Adicionar aos favoritosSanto Amaro da Imperatriz -  SCHoje, 20:546IPHONE XS MAX 64 GB SEMI NOVOS R$ 3.250Adicionar aos favoritosProfissionalBelo Horizonte -  MGHoje, 20:543Iphone 6sR$ 350Adicionar aos favoritosOnlineJuiz de Fora -  MGHoje, 20:541Vendo Edge 20 Pro  (256 gb)R$ 2.300Adicionar aos favoritosRio de Janeiro -  RJHoje, 20:532Apple Watch 7 Até 12X ( Super Promoção Hoje, Toda Linha Apple em Promoção Hoje!! )R$ 2.380Adicionar aos favoritosProfissionalBrasília -  DFHoje, 20:536iPhone 12 128GBR$ 3.600Adicionar aos favoritosNova Iguaçu -  RJHoje, 20:536Iphone 7R$ 800Adicionar aos favoritosOnlineOlinda -  PEHoje, 20:531iPhone 11 64 GB  lacrado R$ 3.000Adicionar aos favoritosJuiz de Fora -  MGHoje, 20:532iPhone 11 + fone de ouvido sem fio !R$ 2.80012x de R$ 233,33Adicionar aos favoritosOnlineCompra SeguraParcelamento sem jurosDesconto no freteDeliveryBrasília -  DFHoje, 20:535Iphone XR 128gb - BrancoR$ 2.86712x de R$ 238,92Adicionar aos favoritosOnlineCompra SeguraParcelamento sem jurosDesconto no freteDeliveryContagem -  MGHoje, 20:531Rastreamento de veiculosAdicionar aos favoritosOnlineManaus -  AMHoje, 20:536DESTAQUESamsung S21 FE 5G na caixa com NFR$ 3.900Adicionar aos favoritosOnlineManaus -  AMHoje, 20:522IPHONE XR 128 GIGAS / MOSTRUÁRIOR$ 2.100Adicionar aos favoritosOnlineProfissionalCampinas -  SPHoje, 20:521Xiaomi Redmi 10A 32gbR$ 750Adicionar aos favoritosOnlineProfissionalCampinas -  SPHoje, 20:523iPhone XR 64gbR$ 1.900Adicionar aos favoritosRio de Janeiro -  RJHoje, 20:521Capa Case Xiaomi Redmi Note 11 4G e 5GR$ 30Adicionar aos favoritosProfissionalSalvador -  BAHoje, 20:526DESTAQUEApple AirPods Pro #3 Geração R$ 800Adicionar aos favoritosRibeirão Preto -  SPHoje, 20:521iPhone XR 64gbR$ 2.00012x de R$ 166,67Adicionar aos favoritosCompra SeguraParcelamento sem jurosDesconto no freteDeliveryRecife -  PEHoje, 20:526iPhone SE 64 gb  val.  350,00R$ 350Adicionar aos favoritosOnlineBelém -  PAHoje, 20:524DESTAQUECarregador iphone 11 pro 12 13 Xr 8 plus original Apple USB-C anatelR$ 195Adicionar aos favoritosRecife -  PEHoje, 20:516DESTAQUECelular MI Light 10 - 5GR$ 1.35012x de R$ 112,50Adicionar aos favoritosCompra SeguraParcelamento sem jurosDesconto no freteDeliveryFlorianópolis -  SCHoje, 20:514Capa Case Silicone AirPods Pro - Transparente\xa0<br><br>R$ 35Adicionar aos favoritosProfissionalSalvador -  BAHoje, 20:516Capa resistente a quedas de borracha para iPhone XS Max!!!R$ 909x de R$ 10,00Adicionar aos favoritosOnlineCompra SeguraParcelamento sem jurosDesconto no freteDeliveryRio de Janeiro -  RJHoje, 20:516Celular Lg k10 pawerR$ 380Adicionar aos favoritosAraruna -  PBHoje, 20:515Adaptador Para Carregamento Sem Fio - Indução Qi Para iPhoneR$ 898x de R$ 11,13Adicionar aos favoritosOnlineCompra SeguraParcelamento sem jurosSuzano -  SPHoje, 20:516Fone de Ouvido Gamer com Microfone IT-Blue LE-2721 Novo Lacrado- Loja Natan Abreu R$ 49Adicionar aos favoritosProfissionalVila Velha -  ESHoje, 20:511iPhone ...

# %%
## EXTRAINDO TEXTOS TÍTULOS ANUNCIOS
title = [x.get_text() for x in title]
title
# Out:
# ['Iphone 12 Pro Max, 256 GB, Graphite',
#  'Motorola Moto G7 Play',
#  'iPhone ',
#  'Iphone 6s ',
#  'Apple Watch 7 Até 12X ( Super Promoção Hoje!! ) Toda Linha Apple!!',
#  'iPhone 7plus ',
#  'IPHONE XSMAX 256 GB SEMI NOVOS DE VITRINE COM GARANTIA ',
#  'iPhone X 64Gb Seminovo ',
#  'iPhone 8 Plus 128gb 88 de bateria ',
#  'iPhone 11 64 GB novo ',
#  'IPHONE XS MAX 64 GB SEMI NOVOS ',
#  'Iphone 6s',
#  'Vendo Edge 20 Pro  (256 gb)',
#  'Apple Watch 7 Até 12X ( Super Promoção Hoje, Toda Linha Apple em Promoção Hoje!! )',
#  'iPhone 12 128GB',
#  'Iphone 7',
#  'iPhone 11 64 GB  lacrado ',
#  'iPhone 11 + fone de ouvido sem fio !',
#  'Iphone XR 128gb - Branco',
#  'Rastreamento de veiculos',
#  'Samsung S21 FE 5G na caixa com NF',
#  'IPHONE XR 128 GIGAS / MOSTRUÁRIO',
#  'Xiaomi Redmi 10A 32gb',
#  'iPhone XR 64gb',
#  'Capa Case Xiaomi Redmi Note 11 4G e 5G',
#  'Apple AirPods Pro #3 Geração ',
#  'iPhone XR 64gb',
#  'iPhone SE 64 gb  val.  350,00',
#  'Carregador iphone 11 pro 12 13 Xr 8 plus original Apple USB-C anatel',
#  'Celular MI Light 10 - 5G',
#  'Capa Case Silicone AirPods Pro - Transparente\xa0<br><br>',
#  'Capa resistente a quedas de borracha para iPhone XS Max!!!',
#  'Celular Lg k10 pawer',
#  'Adaptador Para Carregamento Sem Fio - Indução Qi Para iPhone',
#  'Fone de Ouvido Gamer com Microfone IT-Blue LE-2721 Novo Lacrado- Loja Natan Abreu ',
#  'iPhone 11 64gb Preto ',
#  ' Smartphone Samsung Galaxy A23  128GB 4Gb Ram',
#  'turu c201 sl gyn ',
#  'Redmi Note  9 active 64Gb',
#  'Xiaomi Poco X4 Pro 5G 128Gb + 6Ram  (Garantia 3 Meses)',
#  'Película traseira fibra de carbono iPhone 11 11pro e 11 Pro Max 12 12pro e 12 pro max ',
#  'iPhone 8 64g',
#  'Sansung buds live',
#  ' TENHO 2 RADIO COMUNICADOR DEP 450 UHF',
#  'iPhone 7 Plus, 128 GB , vendo ou troco com volta aceito cartão ',
#  'Iphone 8 - Cinza 64GB',
#  'iPhone 7 32gb ',
#  'iPhone 8 256gb',
#  'Samsung S21fe novo-lacrado ',
#  'Apple Watch série 4']

# %%
# %%time
## DATAFRAME FINAL COM OS DADOS
df_metadados = pd.DataFrame()

## DATA QUE A COLETA FOI REALIZADA. SERÁ UTILIZADA PARA TER UM CONTROLE DE TEMPO DOS DADOS 
data_coleta = datetime.now().date()

print(f"==== COLETA INICIADA ==== ")
for pagina in range(1,101):
  print(f"{pagina}",end=" - ")

  ## URL COM A PAGINAÇÃO (pagina)
  url_inicial = f"https://olx.com.br/celulares?o={pagina}"
  pagina_inicial = requests.get(url_inicial, headers=headers)
  print(pagina_inicial) # response 200 conexão OK, outros valores, houve algum problema

  # CONVERTENDO PÁGINA BYTES PARA OBJETO BEAUTIFULSOUP(que irá ter todas as funções/métodos para fazer o scraping) 
  pagina_inicial = BeautifulSoup(pagina_inicial.content, 'html.parser')
  
  ## EXTRAINDO ID DO ANUNCIO
  id = pagina_inicial.find_all(class_=Link_class)
  ids = [x.get_attribute_list("data-lurker_list_id")[0] for x in id]

  ## EXTRAINDO LINK ANUNCIO
  tags_links = pagina_inicial.find_all(name = "a", class_ =Link_class)
  links = [ x.get_attribute_list("href")[0] for x in tags_links]

  ## EXTRAINDO TÍTULO ANUNCIO
  titulo = pagina_inicial.find_all(class_=Classe_title)
  titulo = [x.get_text() for x in titulo]


  ## EXTRAINDO VALOR ANUNCIO
  valor = pagina_inicial.find_all(class_=Classe_price)
  valor = [x.get_text() for x in valor]

  ## EXTRAINDO LOCALIZAÇÃO ANUNCIO
  local = pagina_inicial.find_all(class_=Classe_location)
  local = [x.get_text() for x in local]

  ## EXTRAINDO DATA ANUNCIO
  data = pagina_inicial.find_all(class_=Classe_post_time)
  data = [x.get_text() for x in data]

  ## VERIFICANDO A QUANTIDADE DE ELEMENTOS PARA CADA VARIÁVEIS
  print(len(ids), len(links),len(titulo), len(valor), len(local), len(data))

  ## CRIANDO DATAFRAME TEMPORÁRIO PARA ARMAZENADOS OS DADOS
  df = pd.DataFrame( list(zip(ids,titulo,valor,local,data,links)),
                    columns = ["ID","TITULO","VALOR","LOCAL","DATA_ANUNCIO","LINK"] )
  
  ## CONDIÇÃO PARA VERIFICAR SE DADOS FORAM COLETADOS
  if len(df) > 0:
    #inserindo no DF a data de coleta
    df.loc[:,'DATA_COLETA_METADADOS'] = data_coleta 

    ## CONCATENANDO DADOS COLETADOS NO DATAFRAME FINAL(df_metadado)
    df_metadados = pd.concat([df_metadados,df])

    print("salvando\n")
    dataHora = datetime.now().strftime('%Y%m%d%H%M')

    ## SALVANDO DF LINKS
    df_metadados.to_csv(f"metadados_olx_telephones_{dataHora}.csv",index=False)

    ## TIME PARA GERAR TEMPO DE "ESPERA" ANTES DE REALIZAR OUTRA REQUISIÇÃO
    # PROCEDIMENTO REALIZADO PARA NÃO SOBRECARREGAR O SERVIDOR
    time.sleep(random.randint(1,2))

print(f"==== COLETA FINALIZADA ==== ")
# Out:
# ==== COLETA INICIADA ====
# 1 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 2 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 3 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 4 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 5 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 6 - <Response [200]>
# 54 54 54 54 54 54
# salvando
#
# 7 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 8 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 9 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 10 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 11 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 12 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 13 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 14 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 15 - <Response [200]>
# 54 54 54 54 54 54
# salvando
#
# 16 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 17 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 18 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 19 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 20 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 21 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 22 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 23 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 24 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 25 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 26 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 27 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 28 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 29 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 30 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 31 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 32 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 33 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 34 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 35 - <Response [200]>
# 54 54 54 54 54 54
# salvando
#
# 36 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 37 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 38 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 39 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 40 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 41 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 42 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 43 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 44 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 45 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 46 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 47 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 48 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 49 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 50 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 51 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 52 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 53 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 54 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 55 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 56 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 57 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 58 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 59 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 60 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 61 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 62 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 63 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 64 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 65 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 66 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 67 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 68 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 69 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 70 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 71 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 72 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 73 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 74 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 75 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 76 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 77 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 78 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 79 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 80 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 81 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 82 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 83 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 84 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 85 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 86 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 87 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 88 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 89 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 90 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 91 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 92 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 93 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 94 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 95 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 96 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 97 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 98 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 99 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# 100 - <Response [200]>
# 50 50 50 50 50 50
# salvando
#
# ==== COLETA FINALIZADA ====
# CPU times: total: 23 s
# Wall time: 5min 37s

# %%
df_metadados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5012 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     5012 non-null   object
#  1   TITULO                 5012 non-null   object
#  2   VALOR                  5012 non-null   object
#  3   LOCAL                  5012 non-null   object
#  4   DATA_ANUNCIO           5012 non-null   object
#  5   LINK                   5012 non-null   object
#  6   DATA_COLETA_METADADOS  5012 non-null   object
# dtypes: object(7)
# memory usage: 313.2+ KB

# %%
##ELIMINANDO DADOS DUPLICADOS
df_metadados_limpos = df_metadados.drop_duplicates(subset=['ID'])
df_metadados_limpos.reset_index(inplace=True,drop=True)
print(df_metadados_limpos.shape)
# Out:
# (4809, 7)
